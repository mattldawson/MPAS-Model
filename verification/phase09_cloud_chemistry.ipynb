# %% [markdown]
# # Phase 9: CAM Cloud Chemistry in MPAS
#
# Verifies TS1 + CAM Cloud aqueous chemistry:
# - DAE solver converges in cloudy cells
# - Sulfate production in cloud layer (700–850 hPa prescribed LWC)
# - Clear-sky cells handled gracefully (zero LWC)
# - 48-hour run completes without solver failures
#
# **Pre-requisite:** `data/jw_480km_cloud_chem/output.nc`
# (JW test with prescribed cloud layer and MIAM cloud chemistry)

# %%
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path("..") / "data" / "jw_480km_cloud_chem"
OUTPUT = DATA_DIR / "output.nc"
assert OUTPUT.exists(), f"Run the Phase 9 test first — {OUTPUT} not found"

ds = nc.Dataset(OUTPUT)
lat = np.degrees(ds["latCell"][:])
lon = np.degrees(ds["lonCell"][:])
nTimes = ds.dimensions["Time"].size

# %% [markdown]
# ## 1. Sulfate Production
#
# Sulfate should increase over time in the cloud layer (700–850 hPa)
# where prescribed LWC > 0.

# %%
# TODO: Update variable name for sulfate
so4_name = "SO4"  # or sulfate naming convention used
if so4_name in ds.variables:
    # Cloud layer levels (~700-850 hPa)
    cloud_levs = slice(3, 6)  # approximate
    so4_cloud = np.array([
        ds[so4_name][t, :, cloud_levs].mean() for t in range(nTimes)
    ])

    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(range(nTimes), so4_cloud, "o-", markersize=3, color="tab:red")
    ax.set_xlabel("Time step")
    ax.set_ylabel("SO4 (mol/mol)")
    ax.set_title("Sulfate in Cloud Layer (700–850 hPa)")
    plt.tight_layout()
    plt.show()
    print(f"SO4 increase: {so4_cloud[-1]/so4_cloud[0]:.2f}x")
else:
    print(f"Variable '{so4_name}' not found — Phase 9 not yet implemented")

# %% [markdown]
# ## 2. Cloudy vs Clear-Sky Cells
#
# Compare sulfate in cells with prescribed cloud water vs clear-sky cells.

# %%
# TODO: Identify cloudy cells from LWC field
print("Will compare SO4 production rates between cloudy and clear-sky cells")
print("Expected: SO4 increases only where LWC > 0")

ds.close()
